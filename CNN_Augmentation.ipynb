# %% [markdown]
# <a href="https://colab.research.google.com/github/snehasingh979/Data-science-with-AI/blob/main/CNN_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pa
import matplotlib.image as mping
import matplotlib.pyplot as plt
import random
from skimage.util import random_noise
from cv2 import resize

from google.colab import files, drive
drive.mount('/content/drive')

from google.colab import files
uploaded = files.upload()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-092ef07c-d6c1-4b06-a72c-0b52b88c28f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-092ef07c-d6c1-4b06-a72c-0b52b88c28f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %% [markdown]
# pip install opencv- python

# %%
img = mping.imread("/content/image.jpg.jpeg")

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
new_img=resize(img,(1500,1150))

# %%
plt.imshow(new_img)
plt.axis('off')
plt.show()
