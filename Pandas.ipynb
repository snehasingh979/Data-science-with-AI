# %% [markdown]
# <a href="https://colab.research.google.com/github/snehasingh979/Data-science-with-AI/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas
#
# pandas is an open-source python library used for data for data manipulation and data analysis

# %% [markdown]
# Why do we use pandas?
#
# pandas is used read,clean,organzie,filter,analze,and manipulate strutureed data efficiently

# %% [markdown]
# feature of pandas
#
# 1.Data manipulation
#
# used to modify organzie and transform data easily

# %% [markdown]
# 2.Data analysis
#
# used to analyze data extract meaningful insights

# %% [markdown]
# 3.Fast processing
#
# handle large dataset efficiently with optimized performace

# %% [markdown]
# 4.Missing value handling
#
# allow easy detection and handling of misssing value

# %% [markdown]
# 5.File handling
#
# can read and write CSV ,excel,json,sql,and many other file formate

# %% [markdown]
# 6.Data filtering
#
# used to select specific row and colums based on condition

# %% [markdown]
# 7.Data cleaning
#
# remove dulicate incorrect or uncessary data

# %% [markdown]
# 8.Statistical analysis
# provide

# %% [markdown]
# Main Data Structure in Pandas

# %% [markdown]
# 1.series A series is one-dimensional labeled aaray that store a single colume of data
#
#
# 2.Data frame A dataframe is two-dimiensional labeled array consisting row and columns

# %% [markdown]
# 1.Creating series

# %%
import pandas as np
marks = np.Series([85,90,78,92,88])
print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# dtype: int64

# %% [markdown]
# creating a series of string

# %%
import pandas as np
fruits = np.Series(['apple','banana','orange','mango'])
print(fruits)
# Out:
# 0     apple
# 1    banana
# 2    orange
# 3     mango
# dtype: object

# %% [markdown]
# creating a series with custom index

# %%
import pandas as np
marks = np.Series([85,90,78,92,88],index=['ram','shyam','hari','gita','sita'])
print(marks)

# %% [markdown]
# creating a series form a dictionary

# %%
import pandas as pd
student = pd.Series({"Name":"Aman","Age":20,"city":"delhi"})
print(student)
# Out:
# Name     Aman
# Age        20
# city    delhi
# dtype: object

# %% [markdown]
# Access value in  a series

# %%
import pandas as pd
marks = pd.Series([85,90,78,92,88],index=['ram','shyam','hari','gita','sita'])
print(marks[2])
# Out:
# 78
# /tmp/ipykernel_4626/698897383.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[2])

# %% [markdown]
# Access value using  custom index

# %%
import pandas as pd
marks = pd.Series([85,90,78,92,88],index=['ram','shyam','hari','gita','sita'])
print(marks['hari'])
# Out:
# 78

# %% [markdown]
# Print Series information

# %%
import pandas as pd
marks = pd.Series([85,90,78,92,88],index=['ram','shyam','hari','gita','sita'])
print(marks.dtype)
# Out:
# int64
